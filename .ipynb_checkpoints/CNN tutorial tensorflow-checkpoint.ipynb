# %%
# https://www.tensorflow.org/tutorials/images/cnn

import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
# Out:
# ...
# 170500096/170498071 [==============================] - 6s 0us/step

# %%
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# ...
# Total params: 56,320
# Trainable params: 56,320
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                65600
# ...

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=10, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 24s 15ms/step - loss: 1.5205 - accuracy: 0.4429 - val_loss: 1.3723 - val_accuracy: 0.5226
# Epoch 2/10
# 1563/1563 [==============================] - 24s 15ms/step - loss: 1.1489 - accuracy: 0.5927 - val_loss: 1.1435 - val_accuracy: 0.5932
# Epoch 3/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.9905 - accuracy: 0.6540 - val_loss: 0.9718 - val_accuracy: 0.6578
# Epoch 4/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.8943 - accuracy: 0.6872 - val_loss: 0.9633 - val_accuracy: 0.6680
# Epoch 5/10
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.8204 - accuracy: 0.7128 - val_loss: 0.9161 - val_accuracy: 0.6865
# Epoch 6/10
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.7657 - accuracy: 0.7330 - val_loss: 0.8961 - val_accuracy: 0.6905
# Epoch 7/10
# ...

# %%
from matplotlib.image import imread

# %%
def pred(img):
    img_reshaped = img.reshape(1, 32, 32, 3) #/ 255
    y_probs = model.predict(img_reshaped)
    y = y_probs.argmax(axis=-1)[0]
    return class_names[y]

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    test = train_images[i]
    res = pred(test)
    plt.title("This is a {}".format(res))
    plt.imshow(test)
plt.show()

# %%
tests = ["cat","frog","truck","truck_2","container"]
plt.figure(figsize=(20,20))
for i in range(len(tests)):
    plt.subplot(5,5,i+1)
    test = plt.imread("images/"+tests[i]+".png")
    res = pred(test)
    plt.title("This is a {}".format(res))
    plt.imshow(test)
plt.show()
